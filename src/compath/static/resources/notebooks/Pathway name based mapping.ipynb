# %% [markdown]
# # ComPath -  Pathway name similarity comparison
#
#
# ##### Author: Daniel Domingo-Fernandez
#
# The goal of this notebook is to support the mapping KEGG pathways to their corresponding Reactome pathways. Based on the similarity of pathway names across different repositories, we can manually confirm later whether the two names represent the same pathway.

# %% [markdown]
# ### Notebook imports

# %%
import time
import sys
import os

import pandas as pd
from collections import defaultdict
from difflib import SequenceMatcher

# %% [markdown]
# ### Notebook configuration

# %%
time.asctime()
# Out:
# 'Mon Jan 29 10:53:11 2018'

# %%
print(sys.version)
# Out:
# 3.4.5 (default, Dec 11 2017, 14:22:24)
# [GCC 4.8.5 20150623 (Red Hat 4.8.5-16)]

# %%
COMPATH_PATH = os.environ['COMPATH']

# %% [markdown]
# ### Load resources

# %%
kegg_excel = os.path.join(COMPATH_PATH,'src','compath','static','resources','excel','kegg_gene_sets.csv')
reactome_excel = os.path.join(COMPATH_PATH,'src','compath','static','resources','excel','reactome_gene_sets.csv')

kegg_dataframe = pd.read_csv(kegg_excel, dtype=object)
reactome_dataframe = pd.read_csv(reactome_excel, dtype=object)

# Remove the 'Homo sapiens' out of the KEGG pathways
kegg_dataframe.columns = [
    kegg_pathway.replace(' - Homo sapiens (human)', '')
    for kegg_pathway in kegg_dataframe
]

# %% [markdown]
# ### Pathway name based mapping

# %%
name_based_mapping = list()

for kegg_pathway in kegg_dataframe.columns.values:
        
    matching = set()
    
    for reactome_pathway in reactome_dataframe.columns.values:
        
        sim_value = SequenceMatcher(None, kegg_pathway, reactome_pathway).ratio()
        
        # Similarity threshold
        if sim_value < 0.8:
            continue
            
        matching.add(reactome_pathway)
        
    # Create an ordered column (alphabetic) for mapping overview table
    
    name_based_mapping.append(matching)
        
    if not matching:
        continue
        
    print("{} has the following matching {}".format(kegg_pathway, matching))
# Out:
# Antigen processing and presentation has the following matching {'Antigen processing-Cross presentation'}
# Apelin signaling pathway has the following matching {'Reelin signalling pathway'}
# Apoptosis has the following matching {'Apoptosis'}
# Arachidonic acid metabolism has the following matching {'Arachidonic acid metabolism'}
# Arginine biosynthesis has the following matching {'Agmatine biosynthesis', 'Pyrimidine biosynthesis', 'Androgen biosynthesis', 'Serine biosynthesis'}
# Axon guidance has the following matching {'Axon guidance'}
# Base excision repair has the following matching {'Base Excision Repair'}
# Biotin metabolism has the following matching {'Nicotinate metabolism'}
# Caffeine metabolism has the following matching {'Creatine metabolism'}
# Calcium signaling pathway has the following matching {'Reelin signalling pathway'}
# Cell cycle has the following matching {'Cell Cycle'}
# Cellular senescence has the following matching {'Cellular Senescence'}
# Chemokine signaling pathway has the following matching {'Reelin signalling pathway'}
# Citrate cycle (TCA cycle) has the following matching {'Citric acid cycle (TCA cycle)'}
# DNA replication has the following matching {'DNA Replication'}
# ECM-receptor interaction has the following matching {'Ligand-receptor interactions'}
# Fanconi anemia pathway has the following matching {'Fanconi Anemia Pathway'}
# Fat digestion and absorption has the following matching {'Digestion and absorption'}
# Fatty acid biosynthesis has the following matching {'Fatty acyl-CoA biosynthesis'}
# Fatty acid metabolism has the following matching {'Fatty acid metabolism'}
# Folate biosynthesis has the following matching {'Agmatine biosynthesis', 'Wax biosynthesis', 'Fructose biosynthesis'}
# Galactose metabolism has the following matching {'Fructose metabolism', 'Glucose metabolism', 'Glycogen metabolism', 'Galactose catabolism'}
# Glutathione metabolism has the following matching {'Glucose metabolism'}
# Glycerolipid metabolism has the following matching {'Glycosphingolipid metabolism'}
# Glycerophospholipid metabolism has the following matching {'Glycosphingolipid metabolism', 'Phospholipid metabolism', 'Glycerophospholipid catabolism'}
# GnRH signaling pathway has the following matching {'Reelin signalling pathway'}
# Histidine metabolism has the following matching {'Histidine catabolism'}
# Inositol phosphate metabolism has the following matching {'Inositol phosphate metabolism'}
# Insulin signaling pathway has the following matching {'Reelin signalling pathway'}
# Linoleic acid metabolism has the following matching {'Sialic acid metabolism', 'Linoleic acid (LA) metabolism'}
# Lipoic acid metabolism has the following matching {'Sialic acid metabolism', 'Linoleic acid (LA) metabolism', 'Arachidonic acid metabolism'}
# Lysine degradation has the following matching {'Glycine degradation'}
# Mismatch repair has the following matching {'Mismatch Repair'}
# Nucleotide excision repair has the following matching {'Nucleotide Excision Repair'}
# PPAR signaling pathway has the following matching {'Reelin signalling pathway'}
# Pentose phosphate pathway has the following matching {'Pentose phosphate pathway disease'}
# Prolactin signaling pathway has the following matching {'Reelin signalling pathway'}
# Propanoate metabolism has the following matching {'Pyruvate metabolism'}
# Protein digestion and absorption has the following matching {'Digestion and absorption'}
# Protein processing in endoplasmic reticulum has the following matching {'Pre-NOTCH Processing in the Endoplasmic Reticulum'}
# Purine metabolism has the following matching {'Purine catabolism', 'Creatine metabolism', 'Proline catabolism'}
# Pyrimidine metabolism has the following matching {'Pyrimidine catabolism'}
# Pyruvate metabolism has the following matching {'Pyruvate metabolism'}
# Rap1 signaling pathway has the following matching {'Reelin signalling pathway'}
# Ras signaling pathway has the following matching {'Reelin signalling pathway'}
# Relaxin signaling pathway has the following matching {'Reelin signalling pathway'}
# Retinol metabolism has the following matching {'Creatine metabolism'}
# Sphingolipid metabolism has the following matching {'Glycosphingolipid metabolism', 'Sphingolipid metabolism', 'Phospholipid metabolism'}
# Steroid biosynthesis has the following matching {'Serine biosynthesis'}
# Steroid hormone biosynthesis has the following matching {'Peptide hormone biosynthesis', 'Serine biosynthesis'}
# Tryptophan metabolism has the following matching {'Tryptophan catabolism'}
# Vitamin digestion and absorption has the following matching {'Digestion and absorption'}
# Wnt signaling pathway has the following matching {'Reelin signalling pathway'}
# alpha-Linolenic acid metabolism has the following matching {'alpha-linolenic acid (ALA) metabolism', 'Linoleic acid (LA) metabolism'}
# mTOR signaling pathway has the following matching {'Reelin signalling pathway'}

# %% [markdown]
# ##### Export column

# %%
for mapped_terms in name_based_mapping:
    
    if not mapped_terms:
        print(".")
    
    # Remove curly brackets
    print(", ".join(str(term) for term in mapped_terms))
# Out:
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# Antigen processing-Cross presentation
# Reelin signalling pathway
# Apoptosis
# .
#
# Arachidonic acid metabolism
# .
#
# Agmatine biosynthesis, Pyrimidine biosynthesis, Androgen biosynthesis, Serine biosynthesis
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# Axon guidance
# .
#
# .
#
# .
#
# .
#
# Base Excision Repair
# .
#
# .
#
# .
#
# Nicotinate metabolism
# .
#
# .
#
# .
#
# Creatine metabolism
# Reelin signalling pathway
# .
#
# .
#
# .
#
# .
#
# Cell Cycle
# Cellular Senescence
# .
#
# .
#
# .
#
# Reelin signalling pathway
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# Citric acid cycle (TCA cycle)
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# DNA Replication
# .
#
# .
#
# .
#
# .
#
# Ligand-receptor interactions
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# Fanconi Anemia Pathway
# Digestion and absorption
# Fatty acyl-CoA biosynthesis
# .
#
# .
#
# Fatty acid metabolism
# .
#
# .
#
# .
#
# .
#
# .
#
# Agmatine biosynthesis, Wax biosynthesis, Fructose biosynthesis
# .
#
# .
#
# .
#
# Fructose metabolism, Glucose metabolism, Glycogen metabolism, Galactose catabolism
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# Glucose metabolism
# Glycosphingolipid metabolism
# Glycosphingolipid metabolism, Phospholipid metabolism, Glycerophospholipid catabolism
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# Reelin signalling pathway
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# Histidine catabolism
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# Inositol phosphate metabolism
# .
#
# .
#
# Reelin signalling pathway
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# Sialic acid metabolism, Linoleic acid (LA) metabolism
# Sialic acid metabolism, Linoleic acid (LA) metabolism, Arachidonic acid metabolism
# .
#
# .
#
# .
#
# .
#
# Glycine degradation
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# Mismatch Repair
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# Nucleotide Excision Repair
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# Reelin signalling pathway
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# Pentose phosphate pathway disease
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# Reelin signalling pathway
# Pyruvate metabolism
# .
#
# .
#
# Digestion and absorption
# .
#
# Pre-NOTCH Processing in the Endoplasmic Reticulum
# .
#
# .
#
# Purine catabolism, Creatine metabolism, Proline catabolism
# Pyrimidine catabolism
# Pyruvate metabolism
# .
#
# .
#
# .
#
# .
#
# Reelin signalling pathway
# Reelin signalling pathway
# .
#
# .
#
# Reelin signalling pathway
# .
#
# .
#
# .
#
# Creatine metabolism
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# Glycosphingolipid metabolism, Sphingolipid metabolism, Phospholipid metabolism
# .
#
# .
#
# .
#
# .
#
# Serine biosynthesis
# Peptide hormone biosynthesis, Serine biosynthesis
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# Tryptophan catabolism
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# Digestion and absorption
# Reelin signalling pathway
# alpha-linolenic acid (ALA) metabolism, Linoleic acid (LA) metabolism
# .
#
# .
#
# .
#
# .
#
# Reelin signalling pathway
# .
